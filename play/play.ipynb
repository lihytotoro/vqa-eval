# %%
import json
path = '/home/cuijunbo/zhihu/vqa_eval/TextOCR_0.1_val.json'
with open(path , 'r') as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['info', 'imgs', 'anns', 'imgToAnns'])

# %%
data['imgs']
# Out:
# {'a7ad2bcb93d48576': {'id': 'a7ad2bcb93d48576',
#   'width': 1024,
#   'height': 673,
#   'set': 'val',
#   'file_name': 'train/a7ad2bcb93d48576.jpg'},
#  'adf07fa720dfe849': {'id': 'adf07fa720dfe849',
#   'width': 1024,
#   'height': 768,
#   'set': 'val',
#   'file_name': 'train/adf07fa720dfe849.jpg'},
#  '9f57624d38c5acd8': {'id': '9f57624d38c5acd8',
#   'width': 1024,
#   'height': 768,
#   'set': 'val',
#   'file_name': 'train/9f57624d38c5acd8.jpg'},
#  '66ca8e0091131754': {'id': '66ca8e0091131754',
#   'width': 1024,
#   'height': 790,
#   'set': 'val',
#   'file_name': 'train/66ca8e0091131754.jpg'},
#  'b3def51bbc6c1af8': {'id': 'b3def51bbc6c1af8',
#   'width': 1024,
#   'height': 768,
#   'set': 'val',
#   'file_name': 'train/b3def51bbc6c1af8.jpg'},
#  'fb2d743942556cf6': {'id': 'fb2d743942556cf6',
#   'width': 1024,
#   'height': 768,
#   'set': 'val',
#   'file_name': 'train/fb2d743942556cf6.jpg'},
#  '001e68b987a389d5': {'id': '001e68b987a389d5',
#   'width': 1024,
# ...

# %%
data['anns']
# Out:
# {'a7ad2bcb93d48576_1': {'id': 'a7ad2bcb93d48576_1',
#   'image_id': 'a7ad2bcb93d48576',
#   'bbox': [76.73, 63.84, 141.41, 30.66],
#   'utf8_string': 'RICHARD',
#   'points': [77.3, 63.84, 217.0, 64.4, 218.14, 94.5, 76.73, 94.5],
#   'area': 4335.63},
#  'a7ad2bcb93d48576_2': {'id': 'a7ad2bcb93d48576_2',
#   'image_id': 'a7ad2bcb93d48576',
#   'bbox': [41.53, 93.93, 206.14, 60.2],
#   'utf8_string': 'moRGAn',
#   'points': [42.09, 93.93, 245.39, 93.93, 247.67, 152.99, 41.53, 154.13],
#   'area': 12409.63},
#  'a7ad2bcb93d48576_3': {'id': 'a7ad2bcb93d48576_3',
#   'image_id': 'a7ad2bcb93d48576',
#   'bbox': [39.82, 183.09, 207.28, 75.53],
#   'utf8_string': 'ALTERED',
#   'points': [42.66, 186.5, 241.99, 183.09, 247.1, 258.62, 39.82, 258.05],
#   'area': 15655.86},
#  'a7ad2bcb93d48576_4': {'id': 'a7ad2bcb93d48576_4',
#   'image_id': 'a7ad2bcb93d48576',
#   'bbox': [41.53, 251.24, 208.98, 88.59],
#   'utf8_string': 'CARBOn',
# ...

# %%
data['imgToAnns']['a7ad2bcb93d48576']
# Out:
# ['a7ad2bcb93d48576_1',
#  'a7ad2bcb93d48576_2',
#  'a7ad2bcb93d48576_3',
#  'a7ad2bcb93d48576_4',
#  'a7ad2bcb93d48576_5',
#  'a7ad2bcb93d48576_6',
#  'a7ad2bcb93d48576_7',
#  'a7ad2bcb93d48576_8',
#  'a7ad2bcb93d48576_9',
#  'a7ad2bcb93d48576_10',
#  'a7ad2bcb93d48576_11',
#  'a7ad2bcb93d48576_12',
#  'a7ad2bcb93d48576_13',
#  'a7ad2bcb93d48576_14',
#  'a7ad2bcb93d48576_15',
#  'a7ad2bcb93d48576_16',
#  'a7ad2bcb93d48576_17',
#  'a7ad2bcb93d48576_18',
#  'a7ad2bcb93d48576_19',
#  'a7ad2bcb93d48576_20',
#  'a7ad2bcb93d48576_21',
#  'a7ad2bcb93d48576_22',
#  'a7ad2bcb93d48576_23',
#  'a7ad2bcb93d48576_24',
#  'a7ad2bcb93d48576_25',
#  'a7ad2bcb93d48576_26',
#  'a7ad2bcb93d48576_27',
#  'a7ad2bcb93d48576_28',
#  'a7ad2bcb93d48576_29',
#  'a7ad2bcb93d48576_30',
#  'a7ad2bcb93d48576_31',
#  'a7ad2bcb93d48576_32',
#  'a7ad2bcb93d48576_33',
#  'a7ad2bcb93d48576_34',
#  'a7ad2bcb93d48576_35',
#  'a7ad2bcb93d48576_36',
#  'a7ad2bcb93d48576_37',
#  'a7ad2bcb93d48576_38',
# ...

# %%
import json
path = '/data/public/multimodal/lihaoyu/vqa_eval/answers/cogvlm/20240403222945/docVQATest.json'
with open(path , 'r') as f:
    data = json.load(f)
# Convert and simplify the structure
transformed_data = [{"questionId": item["question_id"], "answer": item["answer"].replace("</s>", "")} for item in data]

# Print or use the transformed data
print(transformed_data)
out_path = '/data/public/multimodal/lihaoyu/vqa_eval/answers/cogvlm/20240403222945/docVQATest_1200.json'
with open(out_path, 'w') as f:
    json.dump(transformed_data, f)
# Out:
# [{'questionId': 57344, 'answer': '1.2'}, {'questionId': 16384, 'answer': 'Betty Royal'}, {'questionId': 57346, 'answer': '10000'}, {'questionId': 61870, 'answer': '400'}, {'questionId': 57348, 'answer': '50'}, {'questionId': 65129, 'answer': 'Table II'}, {'questionId': 16390, 'answer': '88'}, {'questionId': 57351, 'answer': '12'}, {'questionId': 65131, 'answer': 'Periportal and pericentral'}, {'questionId': 46240, 'answer': 'AAPS'}, {'questionId': 16397, 'answer': '6153'}, {'questionId': 16399, 'answer': 'WJD/R&D'}, {'questionId': 16401, 'answer': 'June 7, 1988'}, {'questionId': 61876, 'answer': '$11,577'}, {'questionId': 16403, 'answer': 'Analytical Research'}, {'questionId': 16404, 'answer': 'William M. Coleman, III'}, {'questionId': 65127, 'answer': 'log(day)'}, {'questionId': 16406, 'answer': 'Lexington, Kentucky'}, {'questionId': 16412, 'answer': 'Southern chemical research conference'}, {'questionId': 16414, 'answer': 'October 25-28, 1988'}, {'questionId': 57378, 'answer': '100
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x =np.linspace(-4,4,10)
y =np.sin(x)

# %%
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()
